# %% [markdown]
# <a href="https://colab.research.google.com/github/yu11009/Homework_2025/blob/main/166osPathGetctime_167osPathGetsize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#166

import os, time

target = input('생성 시간을 볼 파일 이름을 입력하세요: ')

try:
    ctime = os.path.getctime(target)
    print('생성 시간:', time.ctime(ctime))
except Exception as e:
    print(e)

# %%
#167

import os

target = input('파일 크기를 볼 파일 이름을 입력하세요: ')

try:
    size = os.path.getsize(target)
    print('파일 크기:', size, 'bytes')
except Exception as e:
