# %% [markdown]
# <a href="https://colab.research.google.com/github/yu11009/Homework_2025/blob/main/114listLen_115listCount.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#114 요소 개수 구하기

listdata = [2,2,2,3,4,5,1,2,3,6,8,3,25,3,4,6,23,1]
ls = len(listdata)
print(ls)
# Out:
# 18

# %%
#115 특정 요소 개수

listdata = [2,2,2,3,4,5,1,2,3,6,8,3,25,3,4,6,23,1]
c1 = listdata.count(2)
c2 = listdata.count(3)
print(c1)
print(c2)
# Out:
# 4
# 4
