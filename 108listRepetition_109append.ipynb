# %% [markdown]
# <a href="https://colab.research.google.com/github/yu11009/Homework_2025/blob/main/108listRepetition_109append.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#108 리스트 반복

listdata = list(range(3))
ret = listdata*3
print(ret)
# Out:
# [0, 1, 2, 0, 1, 2, 0, 1, 2]

# %%
#109 리스트 요소 추가

listdata = []
for i in range(3):
  txt = input('리스트에 추가할 값을 입력[%d/3]: ' %(i+1))
  listdata.append(txt)
  print(listdata)
# Out:
# 리스트에 추가할 값을 입력[1/3]: 2
# ['2']
# 리스트에 추가할 값을 입력[2/3]: 4
# ['2', '4']
# 리스트에 추가할 값을 입력[3/3]: 5
# ['2', '4', '5']
