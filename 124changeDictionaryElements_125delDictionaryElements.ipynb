# %% [markdown]
# <a href="https://colab.research.google.com/github/yu11009/Homework_2025/blob/main/124changeDictionaryElements_125delDictionaryElements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#124 사전 요소값 변경

names = {'Mary':10999, 'Sams':2111, 'Aimy':9788, 'Tom':20245}
names['Aimy'] = 1000
print(names)
# Out:
# {'Mary': 10999, 'Sams': 2111, 'Aimy': 1000, 'Tom': 20245}

# %%
#125 사전 요소 제거

names = {'Mary':10999, 'Sams':2111, 'Aimy':9788, 'Tom':20245}
del names['Aimy']
print(names)
# Out:
# {'Mary': 10999, 'Sams': 2111, 'Tom': 20245}
