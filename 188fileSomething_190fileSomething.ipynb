# %% [markdown]
# <a href="https://colab.research.google.com/github/yu11009/Homework_2025/blob/main/188fileSomething_190fileSomething.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#188

import csv

with open('population.csv', 'r') as f:
    reader = csv.reader(f)
    header = next(reader)

    for row in reader:
        print(row)


#190

import csv

with open('seoul.csv', 'r') as f:
    data = csv.reader(f)
    header = next(data)

    tmin = 999
    tmax = -999
    tmin_date = ''
    tmax_date = ''

    for row in data:
        if row[2] == '':
            continue
        t = float(row[2])
        if t < tmin:
            tmin = t
            tmin_date = row[0]
        if t > tmax:
            tmax = t
            tmax_date = row[0]

print('최저기온: ', tmin_date, tmin)
print('최고기온: ', tmax_date, tmax)
