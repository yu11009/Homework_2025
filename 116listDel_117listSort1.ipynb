# %% [markdown]
# <a href="https://colab.research.google.com/github/yu11009/Homework_2025/blob/main/116listDel_117listSort1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#116 리스트 제거

listdata = [2,2,2,3,4,5,1,2,3,6,8,3,25,3,4,6,23,1]
del listdata
print(listdata)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3590428385.py in <cell line: 0>()
#       3 listdata = [2,2,2,3,4,5,1,2,3,6,8,3,25,3,4,6,23,1]
#       4 del listdata
# ----> 5 print(listdata)
#
# NameError: name 'listdata' is not defined

# %%
#117 리스트 정렬1
nl = ['Mary', 'Sams', 'Aimy', 'Tom', 'Michale', 'Bob', 'Kelly']
nl.sort()
print(nl)
# Out:
# ['Aimy', 'Bob', 'Kelly', 'Mary', 'Michale', 'Sams', 'Tom']
