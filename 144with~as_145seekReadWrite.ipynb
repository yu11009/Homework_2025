# %% [markdown]
# <a href="https://colab.research.google.com/github/yu11009/Homework_2025/blob/main/144with~as_145seekReadWrite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#144

with open('stockcode.txt', 'r') as f:
   for line_num, line in enumerate(f.readlines()):
      print('%d %s' %(line_num+1, line), end='')

# %%
#145

spos = 105
size = 500

f = open('stockcode.txt', 'r')
h = open('stockcode_part.txt', 'w')

f.seek(spos)
data = f.read(size)
h.write(data)

h.close()
f.close()
