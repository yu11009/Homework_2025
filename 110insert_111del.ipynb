# %% [markdown]
# <a href="https://colab.research.google.com/github/yu11009/Homework_2025/blob/main/110insert_111del.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#110 리스트 특정 위치에 요소 삽입

solarsys = ['태양', '수성', '금성','지구', '화성', '목성', '토성', '토성', '천왕성', '해왕성']
pos = solarsys.index('목성')
solarsys.insert(pos, '소행성')

print(solarsys)
# Out:
# ['태양', '수성', '금성', '지구', '화성', '소행성', '목성', '토성', '토성', '천왕성', '해왕성']

# %%
#111 리스트 특정 위치 요소 제거

solarsys = ['태양', '수성', '금성','지구', '화성', '목성', '토성', '토성', '천왕성', '해왕성']
del solarsys[0]
print(solarsys)
del solarsys[-3]

print(solarsys)
# Out:
# ['수성', '금성', '지구', '화성', '목성', '토성', '토성', '천왕성', '해왕성']
# ['수성', '금성', '지구', '화성', '목성', '토성', '천왕성', '해왕성']
