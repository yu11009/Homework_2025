# %% [markdown]
# <a href="https://colab.research.google.com/github/yu11009/Homework_2025/blob/main/112listRemove_113listRemoveAll.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#112 특정 요소 제거

solarsys = ['태양', '수성', '금성','지구', '화성', '목성', '토성', '토성', '천왕성', '해왕성']
solarsys.remove('태양')
print(solarsys)
# Out:
# ['수성', '금성', '지구', '화성', '목성', '토성', '토성', '천왕성', '해왕성']

# %%
#113 모든 요소 제거

solarsys = ['태양', '수성', '금성','지구', '화성', '목성', '토성', '토성', '천왕성', '해왕성']
del solarsys[1:3]
print(solarsys)
# Out:
# ['태양', '지구', '화성', '목성', '토성', '토성', '천왕성', '해왕성']
