# %% [markdown]
# <a href="https://colab.research.google.com/github/yu11009/Homework_2025/blob/main/136map_137read.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#136

f = lambda x: x*x
args = [1, 2, 3, 4, 5]
ret = map(f, args)
print(list(ret))
# Out:
# [1, 4, 9, 16, 25]

# %%
#137

f = open('stockcode.txt', 'r')
data = f.read()
print(data)
f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1939916209.py in <cell line: 0>()
#       1 #137
#       2
# ----> 3 f = open('stockcode.txt', 'r')
#       4 data = f.read()
#       5 print(data)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'stockcode.txt'
